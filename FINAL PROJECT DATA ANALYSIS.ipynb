# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Import the dataset using Pandas from above mentioned url

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv")
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# # """2. High Level Data Understanding:
#  a. Find no. of rows & columns in the dataset
#  b. Data types of columns.
#  c. Info & describe of data in dataframe."""

# %%
print("the number of raws and columns are")
print(df.shape)
# Out:
# the number of raws and columns are
# (57394, 49)

# %%
print("data types of columns are")
print(df.dtypes)
# Out:
# data types of columns are
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
print("info and description of dataframe are")
print(df.info)
print(df.describe())
# Out:
# info and description of dataframe are
# <bound method DataFrame.info of       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
# ...

# %% [markdown]
# # 3. Low Level Data Understanding :
#  a. Find count of unique values in location column.
#  b. Find which continent has maximum frequency using values
# counts.
#  c. Find maximum & mean value in 'total_cases'.
#  d. Find 25%,50% & 75% quartile value in 'total_deaths'.
#  e. Find which continent has maximum
# 'human_development_index'.
#  f. Find which continent has minimum 'gdp_per_capita'

# %%
print("unique values in location cloumn are")
uni=df.location.unique()
len(uni)
# Out:
# unique values in location cloumn are
# 216

# %%
print("the continent which has more frequency")
df["continent"].value_counts().max
# Out:
# the continent which has more frequency
# <bound method NDFrame._add_numeric_operations.<locals>.max of Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64>

# %%
print("the mean of total_cases are")
print(df["total_cases"].mean())
print("the max of total cases are")
print(df.total_cases.max())
# Out:
# the mean of total_cases are
# 167797.3688753302
# the max of total cases are
# 55154651.0

# %%
print("the quantiles are")
print(df.total_deaths.quantile([0.25,0.50,0.75]))
# Out:
# the quantiles are
# 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %%
print("the continent have mamimum human devlopement index is")
g=df.groupby("continent")
g["human_development_index"].max().idxmax()

# %%
print("the contient have minum gdp per capita")
g["gdp_per_capita"].min().idxmin()
# Out:
# the contient have minum gdp per capita
# 'Africa'

# %% [markdown]
# # Filter the dataframe with only this columns

# %%
df_new=df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]
df_new
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 5. Data Cleaning
#  a. Remove all duplicates observations
#  b. Find missing values in all columns
#  c. Remove all observations where continent column value is
# missing
#  Tip : using subset parameter in dropna
#  d. Fill all missing values with 0

# %%
df_new.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
print("misisng value check")
df_new.isnull().sum()
# Out:
# misisng value check
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
df_new.dropna(subset=["continent"],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5532\877654907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.dropna(subset=["continent"],inplace=True)

# %%
df_cln=df_new.fillna(0)
df_cln
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          0.0           0.0
# 1          Asia  Afghanistan  01/01/20          0.0           0.0
# 2          Asia  Afghanistan  02/01/20          0.0           0.0
# 3          Asia  Afghanistan  03/01/20          0.0           0.0
# 4          Asia  Afghanistan  04/01/20          0.0           0.0
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 6. Date time format :
#  a. Convert date column in datetime format using
# pandas.to_datetime
#  b. Create new column month after extracting month data from
# date
#  column.

# %%
df_cln["date"]=pd.to_datetime(df_cln.date)
df_cln["month"]=pd.DatetimeIndex(df_cln.date).month
df_cln
# Out:
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# ...

# %% [markdown]
# # 7. Data Aggregation:
#  a. Find max value in all columns using groupby function on
# 'continent' column
#  Tip: use reset_index() after applying groupby
#  b. Store the result in a new dataframe named 'df_groupby'.
#  (Use df_groupby dataframe for all further analysis)

# %%
df_group_by=df_cln.groupby("continent").max().reset_index()
df_group_by
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12

# %% [markdown]
# # 8. Feature Engineering :
#  a. Create a new feature 'total_deaths_to_total_cases' by ratio of
#  'total_deaths' column to 'total_cases'

# %%
df_group_by["total_deaths_to_total_cases"]=df_group_by["total_deaths"]/df_group_by["total_cases"]
df_group_by
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month  \
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12
#
# ...

# %% [markdown]
# # 9. Data Visualization :
#  a. Perform Univariate analysis on 'gdp_per_capita' column by
# plotting
#  histogram using seaborn dist plot.
#  b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
#  c. Plot Pairplot on df_groupby dataset.
#  d. Plot a bar plot of 'continent' column with 'total_cases' .
#  Tip : using kind='bar' in seaborn catplo

# %% [markdown]
# # gdp per capita

# %%
sb.distplot(df_group_by["gdp_per_capita"],bins=6)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %% [markdown]
# # scater plot

# %%
sb.scatterplot(data=df_group_by,y="total_cases",x="gdp_per_capita")
# Out:
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='total_cases'>

# %% [markdown]
# # pairplot

# %%
sb.pairplot(df_group_by)

# %% [markdown]
# # bar plot

# %%
sb.catplot(data=df_group_by,x="continent",y="total_cases",kind="bar")
plt.figure(figsize=(20,20))
